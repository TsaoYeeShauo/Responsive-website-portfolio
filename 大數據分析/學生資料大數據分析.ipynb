# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-55f0e447-3230-4a08-bbc7-38a3b62f062c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55f0e447-3230-4a08-bbc7-38a3b62f062c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
#[2] Load the students.csv as a DataFrame by using the Python Pandas
import pandas as pd
import numpy as np

# %%
# create a dataframe with pandas
students = pd.read_csv('students.csv')
# check out the first 5 rows of records of studentsDataFrame
students.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#[3]check out the last 5 rows of records of studentsDataFrame
students.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
#[4]Display the values of columns and index of students DataFrame.
import pandas as pd
students = pd.read_csv('students.csv')
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
#[5]Display the shape of students DataFrame.
students.shape
# Out:
# (395, 33)

# %%
#[6]Display the columns data types of students DataFrame.
students.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
#[7]Display the data types counts of columns of students DataFrame. 
students.dtypes.value_counts()
# Out:
# object    17
# int64     16
# dtype: int64

# %%
#[8]Please select the column of “school” as a Series by using two different methods.
#we will select four columns of dataframe
students_school=students[["school"]]
#then,we can see the first 5 records of new dataframe
students_school.head(5)
# Out:
#   school
# 0     GP
# 1     GP
# 2     GP
# 3     GP
# 4     GP

# %%
#here we will select only one colum of dataframe
#we will only select the director name column
school=students[['school']]

# %%
#check the type of director name
type(school)
# Out:
# pandas.core.frame.DataFrame

# %%
#the second method to select“school”columns of dataframe
#we first define a column name list to the dataframe index operator
cols=['school']

students_school=students[cols]
students_school.head(5)
# Out:
#   school
# 0     GP
# 1     GP
# 2     GP
# 3     GP
# 4     GP

# %%
#[9]Please convert the school Series into a DataFrame and show the first five rows of records of new DataFrame.
#save a Series to a variable
director=students['school']
director.name
# Out:
# 'school'

# %%
# turn a Series into a DataFrame
# this changed to a DataFrame
director.to_frame().head(5)
# Out:
#   school
# 0     GP
# 1     GP
# 2     GP
# 3     GP
# 4     GP

# %%
# we use two Series
director = students['school']
G3 = students['G3']

# %%
#[10]Please display the school name value counts
director.value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
#[11]Please return numbers of non-missing values of school column.
director.count()
# Out:
# 395

# %%
#[12]Please select the column of “G3”, and display basics statistics of this column,such as min, max, mean, median, standard deviations (std), sum
G3.min(),G3.max(),G3.mean(),G3.median(),G3.std(),G3.sum()
# Out:
# (0, 20, 10.415189873417722, 11.0, 4.5814426109978434, 4114)

# %%
#[13]Please display the quantile values of 0.1, 0.3, 0.5, 0.7, 0.9 of the column of “G3”.
G3.quantile([0.1, 0.3, 0.5, 0.7, 0.9])
# Out:
# 0.1     5.0
# 0.3     9.0
# 0.5    11.0
# 0.7    13.0
# 0.9    15.6
# Name: G3, dtype: float64

# %%
#[14]Please show any missing values contained in the column of “G3”.
G3.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# Name: G3, Length: 395, dtype: bool

# %%
#[15]Please create a new column of “G3_by_10”, which the values of this column isequal to column “G3” multiply by 10. And display the first five records of columns “G3” and “G3_by_10”
students['G3_by_10']=0
students.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'G3_by_10'],
#       dtype='object')

# %%
#values of 'G3_by_10' column is equal to column “G3” multiply by 10.
students['G3_by_10']=(students['G3']*10)
students.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'G3_by_10'],
#       dtype='object')

# %%
# display the first five records of columns “G3”
students['G3'].head(5)
# Out:
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# Name: G3, dtype: int64

# %%
# display the first five records of columns“G3_by_10”
students['G3_by_10'].head(5)
# Out:
# 0     60
# 1     60
# 2    100
# 3    150
# 4    100
# Name: G3_by_10, dtype: int64

# %%
#[16]Please display the top 5 final grade of “G3” with the most occurrences by using the chained value_counts() and head() methods.
# check out the G3 value counts
G3.value_counts().head(5)
# Out:
# 10    56
# 11    47
# 0     38
# 15    33
# 8     32
# Name: G3, dtype: int64

# %%
#[17]Please create a new DataFrame students2 with setting the “school” as the index by using two different methods. 
import pandas as pd
students2 = {'School':['Tom', 'nick', 'krish', 'jack'],'address':['NewYork', 'Towertree', 'Taitan', 'jack']} 
df = pd.DataFrame(students2)
print(df)
# Out:
#   School    address
# 0    Tom    NewYork
# 1   nick  Towertree
# 2  krish     Taitan
# 3   jack       jack

# %%
# Import pandas and numpy libraries
import pandas as pd
import numpy as np
# Create a numpy array
nparray = np.array(
    [['Emma', 'Oliver', 'Harry', 'Sophia'],
     ['HR', 'Finance', 'Marketing', 'IT']])
# Create a Student2
dictionary_of_nparray = {
    'school': nparray[0],
    'address': nparray[1]}
# Create the DataFrame
df2 = pd.DataFrame(dictionary_of_nparray)
df2
# Out:
#    school    address
# 0    Emma         HR
# 1  Oliver    Finance
# 2   Harry  Marketing
# 3  Sophia         IT

# %%
#[18]Please delete the column of “address” of student2 DataFrame, and display the columns values after deleting the column. 
df.drop(columns=['address'])
# Out:
#   School
# 0    Tom
# 1   nick
# 2  krish
# 3   jack

# %%
students2 = students.set_index('school')
student2.head(5)

# %%
students2 = pd.read_csv('./students.csv',index_col='school')
students2.head(5)
